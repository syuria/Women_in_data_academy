# %% [markdown]
# **Another way to create a DataFrame**

# %%
import pandas as pd
frame = pd.DataFrame([[8.96, 1884], [7.87, 1149], [7.13, 428]],
                    index = ["Copper", "Iron", "Zinc"],
                    columns = ["Density g/cm3", "Melting Point BC"])
                    
print(frame)
# Out:
#         Density g/cm3  Melting Point BC
# Copper           8.96              1884
# Iron             7.87              1149
# Zinc             7.13               428

# %%
print(frame.loc["Copper"])
# Out:
# Density g/cm3          8.96
# Melting Point BC    1884.00
# Name: Copper, dtype: float64

# %% [markdown]
# **Working with Larger Data Sets**

# %%
import pandas as pd

# %%
data = pd.read_csv("ign.csv")

# %%
data.shape
# Out:
# (18625, 11)

# %%
print(data)
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# 18623                                             Inside
# 18624                                             Inside
#
#                                                      url          platform  \
# 0                 /games/littlebigplanet-vita/vita-98907  PlayStation Vita
# 1      /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita
# 2                              /games/splice/ipad-141070              iPad
# 3                          /games/nhl-13/xbox-360-128182          Xbox 360
# 4                               /games/nhl-13/ps3-128181     PlayStation 3
# ...                                                  ...               ...
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...             Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...     PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681     PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435          Xbox One
# 18624                 /games/inside-playdead/pc-20055740                PC
#
#        score              genre editors_choice  release_year  release_month  \
# 0        9.0         Platformer              Y          2012              9
# 1        9.0         Platformer              Y          2012              9
# 2        8.5             Puzzle              N          2012              9
# 3        8.5             Sports              N          2012              9
# 4        8.5             Sports              N          2012              9
# ...      ...                ...            ...           ...            ...
# 18620    7.6                RPG              N          2016              6
# 18621    9.0  Action, Adventure              Y          2016              6
# 18622    5.8                RPG              N          2016              6
# 18623   10.0          Adventure              Y          2016              6
# 18624   10.0          Adventure              Y          2016              6
#
#        release_day
# 0               12
# 1               12
# 2               12
# 3               11
# 4               11
# ...            ...
# 18620           29
# 18621           29
# 18622           28
# 18623           28
# 18624           28
#
# [18625 rows x 11 columns]

# %%
data.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
data.tail(3)
# Out:
#        Unnamed: 0 score_phrase                                    title  \
# 18622       18622     Mediocre  Star Ocean: Integrity and Faithlessness
# 18623       18623  Masterpiece                                   Inside
# 18624       18624  Masterpiece                                   Inside
#
#                                           url       platform  score  \
# 18622        /games/star-ocean-5/ps4-20035681  PlayStation 4    5.8
# 18623  /games/inside-playdead/xbox-one-121435       Xbox One   10.0
# 18624      /games/inside-playdead/pc-20055740             PC   10.0
#
#            genre editors_choice  release_year  release_month  release_day
# 18622        RPG              N          2016              6           28
# 18623  Adventure              Y          2016              6           28
# 18624  Adventure              Y          2016              6           28

# %%
data["platform"]
# Out:
# 0        PlayStation Vita
# 1        PlayStation Vita
# 2                    iPad
# 3                Xbox 360
# 4           PlayStation 3
#                ...
# 18620               Wii U
# 18621       PlayStation 4
# 18622       PlayStation 4
# 18623            Xbox One
# 18624                  PC
# Name: platform, Length: 18625, dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data["score"].mean()
# Out:
# 6.950459060402666

# %%
data.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
data.mean().round()
# Out:
# Unnamed: 0       9312.0
# score               7.0
# release_year     2007.0
# release_month       7.0
# release_day        16.0
# dtype: float64

# %%
data["score"] / 2
# Out:
# 0        4.50
# 1        4.50
# 2        4.25
# 3        4.25
# 4        4.25
#          ...
# 18620    3.80
# 18621    4.50
# 18622    2.90
# 18623    5.00
# 18624    5.00
# Name: score, Length: 18625, dtype: float64

# %%
data["score"] * 10
# Out:
# 0         90.0
# 1         90.0
# 2         85.0
# 3         85.0
# 4         85.0
#          ...
# 18620     76.0
# 18621     90.0
# 18622     58.0
# 18623    100.0
# 18624    100.0
# Name: score, Length: 18625, dtype: float64

# %%
myfilter = data["score"] > 8

myfilter
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 18620    False
# 18621     True
# 18622    False
# 18623     True
# 18624     True
# Name: score, Length: 18625, dtype: bool

# %%
highscore = data[myfilter]

highscore.head(5)
#Return the first 5 high scores
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
top_ipad_filter = (data["score"] > 8) & (data["platform"] == "iPad") 
filter = data[top_ipad_filter] 
filter.head()
# Out:
#      Unnamed: 0 score_phrase  \
# 2             2        Great
# 26           26      Amazing
# 52           52      Amazing
# 137         137      Amazing
# 247         247      Amazing
#
#                                                  title  \
# 2                                 Splice: Tree of Life
# 26                                             Bastion
# 52                 The World Ends with You: Solo Remix
# 137  The Walking Dead: The Game -- Episode 3: Long ...
# 247  The Walking Dead: The Game -- Episode 5: No Ti...
#
#                                                    url platform  score  \
# 2                            /games/splice/ipad-141070     iPad    8.5
# 26                          /games/bastion/ipad-140874     iPad    9.0
# 52   /games/the-world-ends-with-you-solo-remix/ipad...     iPad    9.5
# 137  /games/the-walking-dead-season-1-episode-3/ipa...     iPad    9.0
# 247  /games/the-walking-dead-season-1-episode-5/ipa...     iPad    9.5
#
#            genre editors_choice  release_year  release_month  release_day
# 2         Puzzle              N          2012              9           12
# 26   Action, RPG              Y          2012              8           30
# 52           RPG              Y          2012              8           27
# 137    Adventure              Y          2012             10           22
# 247    Adventure              Y          2012             11           19

# %% [markdown]
# ## Data Visualisation

# %%
# Setting up the dataset
from sklearn.datasets import load_iris

data = load_iris()
df   = pd.DataFrame(data['data'], columns=data['feature_names'])

df['species'] = data['target']

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### Line Plot

# %%
df.plot()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot.scatter(x='sepal length (cm)', y='sepal width (cm)')

# %%
df.plot.scatter(x='sepal length (cm)', y='petal length (cm)')

# %% [markdown]
# ### Area Plot

# %%
columns = ['sepal length (cm)', 'petal length (cm)', 'petal width (cm)', 'sepal width (cm)']
df[columns].plot.area()

# %% [markdown]
# ### Bar Chart

# %%
df.groupby('species').mean().plot.bar()

# %% [markdown]
# ### Pie Chart

# %%
df.groupby('species').count().plot.pie(y='sepal length (cm)')

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize = (5,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9419CB80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E942161F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E94242670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9426FAC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9429CF40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E942D4460>]],
#       dtype=object)

# %% [markdown]
# ### Kernel Density Function

# %%
df.plot.kde(subplots=True, figsize=(5,9))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9442B970>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9443ACD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9445DF40>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9448DAF0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E944C60D0>],
#       dtype=object)

# %% [markdown]
# ###Box Plot

# %%
columns = ['sepal length (cm)', 'petal length (cm)', 'petal width (cm)', 'sepal width (cm)']
df[columns].plot.box()
#plt.xticks(rotation='vertical') # required to work: import matplotlib as plt

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df, figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E955F3D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9561E760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9564CB50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E95679FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E956B2460>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E956DD7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E956DD8E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9570AD90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E957715E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9579EA30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E957CBE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E95803310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9582E760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9585DBB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E958890A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E958C4490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E958F0910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E9591DE50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E959562E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E95982730>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E959B0B80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E959E09A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E95A17160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E95A3F8E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012E95A69100>]],
#       dtype=object)
