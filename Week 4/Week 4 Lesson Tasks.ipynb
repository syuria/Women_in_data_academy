# %% [markdown]
# Instruction
# ---------------
# Create a CSV file of 15 holiday destinations for a website

# %% [markdown]
# Task 1
# ---------
# Add in a column of destinations

# %%
import pandas as pd

# %%
data_df = {
    'destinations':['Kuala Lumpur',
                   'Malacca',
                   'Penang',
                   'Gunung Mulu National Park',
                   'Langkawi',
                   'Taman Negara National Park',
                   'Cameron Highlands',
                   'Perhentian Islands',
                   'Semenggoh Nature Reserve',
                   'Bako National Park',
                   'Kuching',
                   'Sipadan',
                   'Lambir Hills National Park',
                   'Johor Bahru',
                   'Taiping']
}

df_data = pd.DataFrame(data_df, columns = ['destinations'])

# %%
df_data
# Out:
#                   destinations
# 0                 Kuala Lumpur
# 1                      Malacca
# 2                       Penang
# 3    Gunung Mulu National Park
# 4                     Langkawi
# 5   Taman Negara National Park
# 6            Cameron Highlands
# 7           Perhentian Islands
# 8     Semenggoh Nature Reserve
# 9           Bako National Park
# 10                     Kuching
# 11                     Sipadan
# 12  Lambir Hills National Park
# 13                 Johor Bahru
# 14                     Taiping

# %% [markdown]
# Task 2
# ----------
# Add in a column that shows feedback score out of 10 for that destination destination

# %%
df_data['feedback_score'] = [4,
                            10,
                            3,
                            4,
                            9,
                            1,
                            6,
                            3,
                            8,
                            10,
                            4,
                            2,
                            7,
                            7,
                            5]

# %%
df_data
# Out:
#                   destinations  feedback_score
# 0                 Kuala Lumpur               4
# 1                      Malacca              10
# 2                       Penang               3
# 3    Gunung Mulu National Park               4
# 4                     Langkawi               9
# 5   Taman Negara National Park               1
# 6            Cameron Highlands               6
# 7           Perhentian Islands               3
# 8     Semenggoh Nature Reserve               8
# 9           Bako National Park              10
# 10                     Kuching               4
# 11                     Sipadan               2
# 12  Lambir Hills National Park               7
# 13                 Johor Bahru               7
# 14                     Taiping               5

# %% [markdown]
# Task 3
# ----------
# Add in a column for average hotel star rating for those those destinations.

# %%
df_data['average_hotel_rating'] = [8.2,
                                5.6,
                                3.7,
                                4.8,
                                6.5,
                                8.3,
                                5.9,
                                3.9,
                                6.9,
                                8.4,
                                9.2,
                                6.9,
                                8.3,
                                7.2,
                                6.3]

# %%
df_data
# Out:
#                   destinations  feedback_score  average_hotel_rating
# 0                 Kuala Lumpur               4                   8.2
# 1                      Malacca              10                   5.6
# 2                       Penang               3                   3.7
# 3    Gunung Mulu National Park               4                   4.8
# 4                     Langkawi               9                   6.5
# 5   Taman Negara National Park               1                   8.3
# 6            Cameron Highlands               6                   5.9
# 7           Perhentian Islands               3                   3.9
# 8     Semenggoh Nature Reserve               8                   6.9
# 9           Bako National Park              10                   8.4
# 10                     Kuching               4                   9.2
# 11                     Sipadan               2                   6.9
# 12  Lambir Hills National Park               7                   8.3
# ...

# %% [markdown]
# Task 4
# ---------
# Add in a column for number of all-inclusive hotels within each destination

# %%
df_data['no_all_inclusive_hotel'] = [3,
                                2,
                                6,
                                6,
                                2,
                                5,
                                4,
                                3,
                                7,
                                5,
                                3,
                                1,
                                7,
                                4,
                                3]

# %%
df_data
# Out:
#                   destinations  feedback_score  average_hotel_rating  \
# 0                 Kuala Lumpur               4                   8.2
# 1                      Malacca              10                   5.6
# 2                       Penang               3                   3.7
# 3    Gunung Mulu National Park               4                   4.8
# 4                     Langkawi               9                   6.5
# 5   Taman Negara National Park               1                   8.3
# 6            Cameron Highlands               6                   5.9
# 7           Perhentian Islands               3                   3.9
# 8     Semenggoh Nature Reserve               8                   6.9
# 9           Bako National Park              10                   8.4
# 10                     Kuching               4                   9.2
# 11                     Sipadan               2                   6.9
# 12  Lambir Hills National Park               7                   8.3
# ...

# %% [markdown]
# Task 5
# ----------
# Add in the most visited city in each destination

# %%
df_data['most_visited_city'] = ['Batu Caves',
                   'Jonker Walk',
                   'Butterworth',
                   'Miri',
                   'Kuah',
                   'Kuala Tembeling',
                   'Temerloh',
                   'Besut',
                   'Siburan',
                   'Siburan',
                   'Kota Samarahan',
                   'Semporna',
                   'Borneo',
                   'Batu Pahat',
                   'Ipoh']

# %%
df_data
# Out:
#                   destinations  feedback_score  average_hotel_rating  \
# 0                 Kuala Lumpur               4                   8.2
# 1                      Malacca              10                   5.6
# 2                       Penang               3                   3.7
# 3    Gunung Mulu National Park               4                   4.8
# 4                     Langkawi               9                   6.5
# 5   Taman Negara National Park               1                   8.3
# 6            Cameron Highlands               6                   5.9
# 7           Perhentian Islands               3                   3.9
# 8     Semenggoh Nature Reserve               8                   6.9
# 9           Bako National Park              10                   8.4
# 10                     Kuching               4                   9.2
# 11                     Sipadan               2                   6.9
# 12  Lambir Hills National Park               7                   8.3
# ...

# %% [markdown]
# Save the dataframe into csv file

# %%
df_data.to_csv('data_destination.csv')
